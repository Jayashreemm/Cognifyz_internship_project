# %%
# Task 1 
# Task: Restaurant Ratings

# %%
# imported necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loaded the data set
df=pd.read_csv(r"c:\Users\DELL\Downloads\Dataset .csv")

# %%
#Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
# most common rating
df['Aggregate rating'].value_counts().idxmax()
# Out:
# 0.0

# %%
ratings=df['Aggregate rating']

# %%
plt.figure(figsize=(5,5))
plt.hist(ratings,color='yellow',bins=30,edgecolor='black')
plt.title("Distribution of aggregate rating")
plt.xlabel('Aggregate rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate the average number of votes received by restaurants.
round(df['Votes'].mean(),3)
# Out:
# 156.91
