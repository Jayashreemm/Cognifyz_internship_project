# %%
# Task: Restaurant Reviews

# %%
# imported required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loaded the data set
df=pd.read_csv(r"c:\Users\DELL\Downloads\Dataset .csv")

# %%
# Analyze the text reviews to identify the mostcommon positive and negative keywords.

# %%
df['Rating text']
# Out:
# 0       Excellent
# 1       Excellent
# 2       Very Good
# 3       Excellent
# 4       Excellent
#           ...
# 9546    Very Good
# 9547    Very Good
# 9548         Good
# 9549    Very Good
# 9550    Very Good
# Name: Rating text, Length: 9551, dtype: object

# %%
positive_data=df[df['Aggregate rating']>=2.5]

# %%
positive_keywords=positive_data['Rating text'].unique()
positive_keywords
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average'], dtype=object)

# %%
# data visualization on positive reviews
plt.figure(figsize=(4,5))
plt.hist(positive_data['Rating text'],label=positive_keywords)
plt.title("Positive Data")
plt.show()

# %%
Negative_data=df[(df['Aggregate rating']<2.5)]

# %%
Negative_words=Negative_data['Rating text'].unique()

# %%
# data visualization on negative review
plt.figure(figsize=(4,5))
plt.hist(Negative_data['Rating text'],label=Negative_words)
plt.title("Negative data")
plt.show()

# %%
# Calculate the average length of reviews and explore 
# if there is a relationship between review length and rating.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df['Rating_text_length']=df['Rating text'].apply(len)

# %%
plt.figure(figsize=(4,5))
sns.scatterplot(x="Rating_text_length",y="Aggregate rating",data=df,color='red')
plt.show()
