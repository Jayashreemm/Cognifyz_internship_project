# %%
# Task 3: Price Range Distribution

# %%
# imported required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"c:\Users\DELL\Downloads\Dataset .csv")
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df['Restaurant Name'].values
price_count=df['Price range'].value_counts()

# %%
#Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants
plt.figure(figsize=(4,4))
plt.hist(df['Price range'],color='b')
plt.title('Distribution of price range')
plt.xlabel('Price Range')
plt.ylabel('Counts')
plt.show()

# %%
#Calculate the percentage of restaurants in each price range category.
x=df['Price range'].value_counts(normalize=True)*100
x
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: proportion, dtype: float64

# %%
# piechart for data visualization
plt.figure(figsize=(5,5))
plt.pie(x,labels=x.index,autopct='%1.1f%%')
plt.title("price range distribution")
plt.show()
