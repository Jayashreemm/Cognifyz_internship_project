# %%
# Task 4:Online Delivery

# %%
# imported required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"c:\Users\DELL\Downloads\Dataset .csv")

# %%
#Determine the percentage of restaurants that offer online delivery.
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
countofonlinedelivery=df[df['Has Online delivery']=='Yes'].shape[0]
# Out:
# 9551

# %%
total_no_of_restaurants=df.shape[0]

# %%
Restaurants_with_online_delivery=round((countofonlinedelivery/total_no_of_restaurants)*100,2)
Restaurants_with_online_delivery
# Out:
# 25.66

# %%
#Compare the average ratings of restaurants with and without online delivery
avgrating_with_onl_del=round(df[df['Has Online delivery']=='Yes']['Aggregate rating'].mean(),2)
avgrating_without_onl_del=round(df[df['Has Online delivery']=='No']['Aggregate rating'].mean(),2)

# %%
avgrating_with_onl_del
# Out:
# 3.25

# %%
avgrating_without_onl_del
# Out:
# 2.47

# %%
labels = ['With Online Delivery', 'Without Online Delivery']
avg_ratings = [avgrating_with_onl_del, avgrating_without_onl_del]
plt.figure(figsize=(5,5))
plt.bar(labels, avg_ratings, color=['blue','orange'])
plt.title('Average Ratings of Restaurants with and without Online Delivery')
plt.ylabel('Average Rating')
plt.show()
